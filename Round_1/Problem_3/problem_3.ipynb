# %%
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Task

# %%
img = cv2.imread("task/Problem_3_Part_1.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,16))
plt.imshow(img)

# %%
img = cv2.imread("task/Problem_3_Part_2.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 16))
plt.imshow(img)

# %% [markdown]
# # Solution

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
# 0
# 0.6
