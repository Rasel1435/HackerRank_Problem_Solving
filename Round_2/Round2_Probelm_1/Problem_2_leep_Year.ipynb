# %% [markdown]
# # Task

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("task/leep_year_1.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 16))
plt.imshow(img)

# %%
img = cv2.imread("task/leep_year_2.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 16))
plt.imshow(img)

# %% [markdown]
# # Solution

# %%
def is_leap(year):
    leap = False

    # Write your logic here
    if year % 400 == 0:
        return True
    if year % 100 == 0:
        return False
    if year % 4 == 0:
        return True
    return leap


year = int(input())
print(is_leap(year))
# Out:
# False
