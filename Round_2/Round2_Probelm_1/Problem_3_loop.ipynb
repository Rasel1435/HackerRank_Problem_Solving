# %% [markdown]
# # Task

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("task/Round_2_task_3.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 16))
plt.imshow(img)

# %% [markdown]
# # Solution

# %%
if __name__ == "__main__":
    n = int(input())

    for i in range(n):
        print(i+1, end="")
# Out:
# 12345
